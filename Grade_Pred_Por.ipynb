# %%
import pandas as pd
df = pd.read_csv("student-por.csv")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        4   0  11  11
# 1    ...      5        3      3     1     1      3        2   9  11  11
# 2    ...      4        3      2     2     3      3        6  12  13  12
# 3    ...      3        2      2     1     1      5        0  14  14  14
# 4    ...      4        3      2     1     2      5        0  11  13  13
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [649 rows x 33 columns]

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# std      0.955717    1.051093    1.175766    0.924834    1.284380    1.446259
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    2.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  649.000000  649.000000  649.000000  649.000000
# mean     3.659476   11.399076   11.570108   11.906009
# std      4.640759    2.745265    2.913639    3.230656
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   10.000000   10.000000   10.000000
# 50%      2.000000   11.000000   11.000000   12.000000
# 75%      6.000000   13.000000   13.000000   14.000000
# max     32.000000   19.000000   19.000000   19.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
#  19  nursery     649 non-null    object
#  20  higher      649 non-null    object
#  21  internet    649 non-null    object
#  22  romantic    649 non-null    object
#  23  famrel      649 non-null    int64
#  24  freetime    649 non-null    int64
#  25  goout       649 non-null    int64
#  26  Dalc        649 non-null    int64
#  27  Walc        649 non-null    int64
#  28  health      649 non-null    int64
#  29  absences    649 non-null    int64
#  30  G1          649 non-null    int64
#  31  G2          649 non-null    int64
#  32  G3          649 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 167.4+ KB

# %%
#EDA
import matplotlib.pyplot as plt
df["school"].value_counts().plot(kind="bar",color="orange")
plt.title("Distribution of schools")
plt.show()

df["sex"].value_counts().plot(kind="bar",color="green")
plt.title("Distribution of boys and girls")
plt.show()

df["Mjob"].value_counts().plot(kind="bar",color="green")
plt.title("Jobs done by mother")
plt.show()

df["Fjob"].value_counts().plot(kind="bar",color="green")
plt.title("Jobs done by father")
plt.show()

plt.hist(df["age"],color="red")
plt.title("Distribution of age across schools")
plt.show()

df["G1"].value_counts().plot(kind="bar",color="green")
plt.title("No. of students scoring first period grade in Portuguese(1=Lowest,20=Highest)")
plt.show()

df["G2"].value_counts().plot(kind="bar",color="green")
plt.title("No. of students scoring second period grade in Portuguese(1=Lowest,20=Highest)")
plt.show()

df["G3"].value_counts().plot(kind="bar",color="green")
plt.title("No. of students scoring final grade in Portuguese(1=Lowest,20=Highest)")
plt.show()

# %%
#standardization
num_col = df.select_dtypes(include="number").columns
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
df[num_col] = SS.fit_transform(df[num_col])
df.head()
# Out:
#   school sex       age address famsize Pstatus      Medu      Fedu     Mjob  \
# 0     GP   F  1.031695       U     GT3       A  1.310216  1.540715  at_home
# 1     GP   F  0.210137       U     GT3       T -1.336039 -1.188832  at_home
# 2     GP   F -1.432980       U     LE3       T -1.336039 -1.188832  at_home
# 3     GP   F -1.432980       U     GT3       T  1.310216 -0.278983   health
# 4     GP   F -0.611422       U     GT3       T  0.428131  0.630866    other
#
#        Fjob  ...    famrel  freetime     goout      Dalc      Walc    health  \
# 0   teacher  ...  0.072606 -0.171647  0.693785 -0.543555 -0.997695 -0.371042
# 1     other  ...  1.119748 -0.171647 -0.157380 -0.543555 -0.997695 -0.371042
# 2     other  ...  0.072606 -0.171647 -1.008546  0.538553  0.560678 -0.371042
# 3  services  ... -0.974536 -1.123771 -1.008546 -0.543555 -0.997695  1.012903
# 4     other  ...  0.072606 -0.171647 -1.008546 -0.543555 -0.218508  1.012903
#
#    absences        G1        G2        G3
# 0  0.073433 -4.155470 -0.195820 -0.280658
# 1 -0.357863 -0.874570 -0.195820 -0.280658
# 2  0.504730  0.219064  0.491137  0.029116
# 3 -0.789159  0.948153  0.834615  0.648663
# 4 -0.789159 -0.145481  0.491137  0.338889
#
# [5 rows x 33 columns]

# %%
#label encoding
cat_col = df.select_dtypes(include="object").columns
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
for col in cat_col:
    df[col] = LE.fit_transform(df[col])
df.head()
# Out:
#    school  sex       age  address  famsize  Pstatus      Medu      Fedu  Mjob  \
# 0       0    0  1.031695        1        0        0  1.310216  1.540715     0
# 1       0    0  0.210137        1        0        1 -1.336039 -1.188832     0
# 2       0    0 -1.432980        1        1        1 -1.336039 -1.188832     0
# 3       0    0 -1.432980        1        0        1  1.310216 -0.278983     1
# 4       0    0 -0.611422        1        0        1  0.428131  0.630866     2
#
#    Fjob  ...    famrel  freetime     goout      Dalc      Walc    health  \
# 0     4  ...  0.072606 -0.171647  0.693785 -0.543555 -0.997695 -0.371042
# 1     2  ...  1.119748 -0.171647 -0.157380 -0.543555 -0.997695 -0.371042
# 2     2  ...  0.072606 -0.171647 -1.008546  0.538553  0.560678 -0.371042
# 3     3  ... -0.974536 -1.123771 -1.008546 -0.543555 -0.997695  1.012903
# 4     2  ...  0.072606 -0.171647 -1.008546 -0.543555 -0.218508  1.012903
#
#    absences        G1        G2        G3
# 0  0.073433 -4.155470 -0.195820 -0.280658
# 1 -0.357863 -0.874570 -0.195820 -0.280658
# 2  0.504730  0.219064  0.491137  0.029116
# 3 -0.789159  0.948153  0.834615  0.648663
# 4 -0.789159 -0.145481  0.491137  0.338889
#
# [5 rows x 33 columns]

# %%
#split the variables
X = df.drop("G3",axis=1)
Y = df["G3"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb_model = GradientBoostingRegressor(n_estimators = 100,random_state = 42,learning_rate = 0.1)
gb_model.fit(X_train,Y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
Y_pred = gb_model.predict(X_test)

# %%
from sklearn.metrics import root_mean_squared_error,r2_score
rmse = root_mean_squared_error(Y_test,Y_pred)
r2 = r2_score(Y_test,Y_pred)
print("Root mean squared error:",round(rmse,2))
print("R2 score:",round(r2,2))
# Out:
# Root mean squared error: 0.41
# R2 score: 0.82

# %%
#cross validation
import numpy as np
rmse = []
r2 = []
for i in range(1,101):
    from sklearn.model_selection import train_test_split
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,random_state=i)
    gb_model.fit(X_train,Y_train)
    Y_pred = gb_model.predict(X_test)
    rmse.append(root_mean_squared_error(Y_test,Y_pred))
    r2.append(r2_score(Y_test,Y_pred))
print("Root mean squared error:",round(np.mean(rmse),2))
print("R2 score:",round(np.mean(r2),2))
# Out:
# Root mean squared error: 0.42
# R2 score: 0.82

# %%
#grid search CV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Define parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [2, 3, 4],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Model
gb_model = GradientBoostingRegressor(random_state=42)

# GridSearchCV
gv_model = GridSearchCV(
    estimator=gb_model,
    param_grid=param_grid,
    cv=5,               
    scoring='r2',
    n_jobs=-1            
)

# Fit
gv_model.fit(X_train, Y_train)

# Predictions
Y_pred = gv_model.predict(X_test)

# Evaluation
rmse = root_mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print("Best Params:", gv_model.best_params_)
print("Root Mean Squared Error:", round(rmse, 2))
print("R2 Score:", round(r2, 2))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best Params: {'learning_rate': 0.05, 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# Root Mean Squared Error: 0.39
# R2 Score: 0.84
