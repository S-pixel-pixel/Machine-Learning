# %%
from apyori import apriori

import pandas as pd

# Data Preprocessing
df = pd.read_csv("C:\\Users\\sujey\\Downloads\\Assignments\\Association Rules\\Association Rules\\Online retail.csv", header = None)
df
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
trans = []

for i in range(0, 7501):
  trans.append([str(df.values[i,j]) for j in range(0, 20)])

# %%
assoc_rules = apriori(transactions = trans,min_support = 0.003,min_confidence = 0.2,min_lift = 3,min_length = 2,max_length = 2)

# %%
final_op = list(assoc_rules)
final_op
# Out:
# [RelationRecord(items=frozenset({'light cream', 'chicken'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)]),
#  RelationRecord(items=frozenset({'mushroom cream sauce', 'escalope'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]),
#  RelationRecord(items=frozenset({'escalope', 'pasta'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
# ...

# %%
# Out:
# 0.29059829059829057

# %%
a=[]
b=[]
c=[]
d=[]
e=[]

for i in range(0,9):
    a.append(final_op[i][2][0][0])
    b.append(final_op[i][2][0][1])
    c.append(final_op[i][1])
    d.append(final_op[i][2][0][2])
    e.append(final_op[i][2][0][3])

a = pd.DataFrame(a)
b = pd.DataFrame(b)
c = pd.DataFrame(c)
d = pd.DataFrame(d)
e = pd.DataFrame(e)

# %%
final_df = pd.concat([a,b,c,d,e],axis=1)
final_df.columns = ["Base","Add","Support","Confidence","Lift"]
final_df
# Out:
#                    Base          Add   Support  Confidence      Lift
# 0           light cream      chicken  0.004533    0.290598  4.843951
# 1  mushroom cream sauce     escalope  0.005733    0.300699  3.790833
# 2                 pasta     escalope  0.005866    0.372881  4.700812
# 3         fromage blanc        honey  0.003333    0.245098  5.164271
# 4         herb & pepper  ground beef  0.015998    0.323450  3.291994
# 5          tomato sauce  ground beef  0.005333    0.377358  3.840659
# 6           light cream    olive oil  0.003200    0.205128  3.114710
# 7     whole wheat pasta    olive oil  0.007999    0.271493  4.122410
# 8                 pasta       shrimp  0.005066    0.322034  4.506672

# %%
#1.	What is lift and why is it important in Association rules?
#   Lift is important in association rules as it hepls us find how much the sales of one product increases due to the other product
#2.	What is support and Confidence. How do you calculate them?
# Support is find individual probabities of the items. While confidence is how much % confident we are that a person will buy product 2 if he purchased 
#product 1.
# Calculation:
#Support = P(A)/P(Total)
#Confidence = P(A/B) = P(A∩B)/P(B)
#3.	What are some limitations or challenges of Association rules mining?
# The limitations are:
# 1) One major challenge is the potential for irrelevant or trivial rules, especially when dealing with large datasets or setting inappropriate 
#    thresholds for support and confidence
# 2) Other challenges include computational complexity, especially for large datasets, and the difficulty of interpreting the results, especially when 
#    dealing with complex relationships or sparse data.
